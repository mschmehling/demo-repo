# %%
# Helpful Notes
# *Make sure everything is perpendicular
# *Save EVERYTHING often, both the SketchUp file and the OSM
# *Make sure to reopen/reload the OSM when you make updates

# %%
# In SketchUp Application

# For adding toolbars
# 	- View>Toolbars> then select the ones you want, make sure you have the OpenStudio toolbar
# 	- If, there is no OpenStudio toolbar option
# 		· Download the OpenStudio .rb file from the internet and save it in the pathway 
# 			§ C:\Users\%userprofile%\AppData\Roaming\SketchUp\SketchUp 2022\SketchUp\Plugins
			
# For importing the drawing(s)

# 	· For the first drawing, import the drawing then for the remaining, if there are other floors…
# 		· Make sure the drawings are imported as jpg
# 	· Right click on the first drawing > reload > import the new drawing. This imports the new drawing at the same size to ensure the geometry matches.
	
# For Windows:
# 	· Get dimensions from the drawings
# 	· Draw windows in a new layer called "windows" or "white surfaces"
# 		· Any new surface here
# 		· If some of the surfaces are not in the "windows" or "white surfaces" layer, chose the tag icon and then the tag icon should be on the cursor
# 		· Next, choose the surfaces that are not in the correct layer.
# 		· Save this as a separate file (i.e. 2022.11.2-windows.skp)
# 		· This allows you to hide the white surfaces later on and see the projected surfaces, it also makes editing easier 
# 	· Draw rectangles onto the surfaces making sure to be 1" from the edge at minimum
# 	· Copy and Paste in Place the windows onto the surface to create window
# 	· Can change the surface type using the Inspector tool 
# 	OR
# 	· If you know the window-to-wall ratio:
# 		· Go into Extensions > Open Studio User Scripts >  Alter or Add User Elements > Set Window to Wall Ratio

	
# For Space Type
# 	• Go into the inspector and delete all of the default space types 
# 	• Go to Extensions > Open Studio User Scripts > On demand Template Generators> Space type and construction set wizard to set the space types for the model
# 	• When you've chosen a space type and need to fix it: use the "Set Attributes for Selected Spaces" button, it has the hammer and wrench in it
# 	• How to add new spaces types back into a model
		
	
# To make SketchUp scene for each floor (this helps when there are multiple floors and they are stacked on top of each other):
# 	• Extensions > Visualization > Make SketchUp Scene for each floor

# For Boundary Conditions:
# 	• Extensions > Open Studio User Scripts > Alter or Add More Elements > Set Boundary Condition of Surfaces in Select Spaces
# 		· Here you can make surfaces outdoor, adiabatic, etc.

# For Construction Type
# 	• First highlight the entire model and select the SURFACE MATCHING button in the toolbar (looks like a surface with 2 arrows going through it both ways)
# 	• Next, go to Camera > View > Top (or bottom)
# 	• Then select the entire model (i.e. all of the ceiling (or floor) surfaces)
# 	• Then go to Extensions > Open Studio User Scripts >  Alter or Add User Elements > Set Boundary Conditions of Surfaces in Selected Spaces 
# 	• Then choose the drop down menus accordingly, do not forget to pick a construction
# *If you need to change certain surfaces
# 	• Open inspector and then choose the surface you want to choose a construction
# 		· You can select multiple surfaces at once --as long as they have the same construction type-- by holding down shift and selecting the surfaces
# *If you the scope of the project does not include certain rooms within the building, therefore there is empty space within the model
# 	• Extensions > Open Studio User Scripts >  Alter or Add User Elements > Make Selected Surfaces Adiabatic and Assign a Construction

# For Thermal Zones
# 	• To assign thermal zones go to Extensions > Open Studio User Scripts >  Alter or Add User Elements > Add Thermal Zone For Spaces With No Thermal Zone
# 	• You can check that spaces are assigned thermal zones by selecting the RENDER BY THERMAL ZONE button in the toolbar
# 	• When you do this, make sure to reopen the model in OpenStudio application
	
# Extensions > Open Studio User Scripts >  Alter or Add User Elements
# 	Here you can add or alter numerous elements of the model.

# %%
# In OpenStudio Application https://openstudio.net/

# Setting the Weather
# 	• Google energyplus.net and look up city > download the file and save in downloads, make sure to unzip the file
# 	• Open OpenStudio app and open the osm file that you are working in
# 	• Under the Site tab, next to Weather file, select "change weather file" and choose the proper file
# 	• Then, next to Design days, select "import ddy file" and choose proper file
# 	• In the All column select the box and then unselect the ".4% Condos Enth=>" and the "99.6% Condns WS=>" boxes. After this press the red X button at the bottom of the window
# 		MDB = mean dry bulb
# 		MCDB = mean coincident dry bulb
# 		DP = dew point
# 		WS = wind speed
# 		Enth = Enthalpy
# 		WB = wet bulb
# 		DB = dry bulb
# 	• You can change the units by going to Preferences > Units
# 	• In SketchUp: Extensions > Open Studio User Scripts > Building Component Library > Get BCL Weather File > then chose the location of the building (i.e. Wilmington and chose Wilmington NC International Airport)
	
# Setting Thermal Zones 
# 	1. Go to Components & Measures > Apply MeasureNow > press the arrow next to Whole Building > press the arrow next to Space Types > then choose Rename spaces based on Openstudio-standards
# 		a. If this script is not present:
# 		· Go to Preferences > Change My Measures Directory > then follow this pathway C:\Users\%userprofile%\OneDrive - JLL\Documents\GitHub\JLL_OpenStudio_Measures-main\JLL_OpenStudio_Measures-main and select this folder
# 		· Then you go back to the first step
# 	2. Once the measure was run, Accept Changes
# 		a. If there is an error open VS Code to find the issue
# 	3. Next go to the Thermal Zones tab, make sure the Name column was renamed correctly and is no longer "Thermal Zone 123"
# 		a. Make sure to reload the .osm in SketchUp after you have made these changes
# 	4. On the right side of the screen select the 
# 	5. You can go into the tab below Thermal Zones, called HVAC Systems, to look at the various systems in place.
# 		a. Choose from the drop down menu in the top right area.
# 	6. Rename something based on thermal zone script

# Constructions and Materials
# 	• You can add constructions/materials to your model by going into the Constructions tab 
# 	• To add a new construction/material press the green + button in the bottom left corner while in the Construction Sets or Material tab
# 		○ Next utilize the menu of materials on the right side of the screen and drag and drop the materials to their appropriate locations accordingly
# 	• Navigate to the menus on the right side of the screen and drag the chosen materials to t
# 	• Adding constructions and then materials and linking the materials to the constructions.
# 	• Then you can go in SketchUp, reload the model, and open the inspector the check that the constructions are updated

# Visualizing model in OS
# 	• You are able to view the model within the OS Application within the Geometry tab on the left side of the window
# 		○ Here you are able to render the space how you like, chose which story you want to look at, etc.
# 	• This allows you to look at the model without having to navigate to SketchUp and reloading the model there

# Running the model
# 	1. Go into the Measures tab and drag the OpenStudio Results measure to the ____ section of the Measures tab
# 	2. Then go into the Run Simulation tab and select the play button in the top left corner
# 	3. If the simulation does not run properly, open the OSM in Vscode and identify the issue.
# 	4. If the simulation runs correctly:
# 		a. Go into the Results summary tab, right below the Run Simulation tab.
# 		b. Here, OpenStudio creates an analysis of the model that can be downloaded.
